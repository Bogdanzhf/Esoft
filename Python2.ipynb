# %% [markdown]
# ### Блок 1: Python: print(), переменные и константы

# %% [markdown]
# #### Вопросы
#
# 1. Что делает функция print()?
# 2. Чем переменная отличается от константы?

# %% [markdown]
# #### Практика
#
# 1. Создай переменную age и сохраните в ней число 25. Выведи на экран с помощью print()
# 2. В переменной a = '10' хранится строка. Преобразуй её в число и сложи с 5
# 3. Почему переменная name = "31" — это строка, а не число?
# 4. Исправь ошибку:

# %%
banka_ovoshchei = "Огурцы"

# %% [markdown]
# 5. Напиши программу, которая запрашивает имя пользователя (input) и выводит приветствие с этим именем.

# %% [markdown]
# ### Блок 2: Python: функции

# %% [markdown]
# #### Вопросы
#
# 1. Что такое функция?
# 2. Какие виды принимаемых параметров/аргумментов есть у функции?

# %% [markdown]
# #### Практика
# 1. Напиши функцию say_hello(), которая возвращает: Привет, <имя>! И вызови данную функцию, чтобы она написала приветствие

# %% [markdown]
# 2. Создай функцию empty(), которая ничего не делает(всеми способами, которые знаешь)

# %% [markdown]
# ### Блок 3: Python: модули

# %% [markdown]
# #### Вопросы
#
# 1. Зачем нужны модули и как их вызвать?
# 2. Какие встроенные модули знаешь?

# %% [markdown]
# #### Практика
#
# 1. Напиши несколько различных видов импорта:
#   - обычный импорт модуля
#   - импорт конкретноый функции
#   - импорт с изменением названия
#   - импорт всех функций

# %% [markdown]
# ### Блок 4: Python: простые типы данных

# %% [markdown]
# #### Вопросы
#
# 1. Какие типы данных ты впринципе знаешь?
# 2. Какие отличия int от float?
# 3. Дляч чего используется None?

# %% [markdown]
# #### Практика
#
# 1. Пропиши выражение с применением различнй арифметических операторов и объясни их приоритеты

# %% [markdown]
# ### Блок 5: Python: ветвления

# %% [markdown]
# #### Вопросы
#
# 1. Какой тип данных возвращает условие 5 > 3?
# 2. Какие есть условные консрукции и что они означают?
# 3. Что такое тернарный оператор?
# 4. Какая разница между and, or, not

# %% [markdown]
# #### Практика
#
# 1. Напиши условие: если x > 10, вывести "Большое число", иначе — "Малое число"

# %% [markdown]
# 2. Напиши условие, которое проверяет, лежит ли число в диапазоне от 10 до 20. Если меньше 1, то вывести "Маленькое", если больше 20, то вывести "Большое"

# %% [markdown]
# 3. Приведи пример использвоания тернарного оператора

# %% [markdown]
# ### Блок 6: Python: списки

# %% [markdown]
# #### Вопросы
#
# 1. Какой тип данных у []?
# 2. Что такое список?
# 3. Как работают индексы и срезы?
# 4. Знаешь ли что такое list comprehension?
# 5. Какие функции знаешь у списка?

# %%
a = [x * 2 for x in range(5) if x % 2 == 0]
print(a)
# Out:
# [0, 4, 8]

# %% [markdown]
# #### Практика:
#
# 1. Создай список из чисел от 1 до 5

# %% [markdown]
# 2. К созданному списку добавь элемент 100 и удали элемент с индексом, а затем конкретный элемент

# %% [markdown]
# ### Блок 7: Кортежи

# %% [markdown]
# #### Вопросы
#
# 1. Что такое кортеж ?
# 2. Какие отличия от спсика?
# 3. Какие функции можно применять к кортежу?

# %% [markdown]
# ### Блок 8: Строки

# %% [markdown]
# #### Вопросы
#
# 1. Какая функция овтечает за то, чтобы перевести в нижний регистр?
# 2. - Верхний?
# 3. Выполни вывод с помощью f строк

# %% [markdown]
# ### Блок 9: словари

# %% [markdown]
# #### Практика
#
# 1. Создай словарь

# %% [markdown]
# 2. Добавь элемент в слвоарь

# %% [markdown]
# 3. Выведи ключи, значения и пары словаря {'x':10,'y':20}.

# %% [markdown]
# ### Блок 10: Множества

# %% [markdown]
# #### Практика
#
# 1. Создай множество с элементами 1, 2, 3.

# %% [markdown]
# 2. Создай пустое множество

# %% [markdown]
# 3. Создай множество и добавь к нему элемент - некую строку

# %% [markdown]
# ### Блок 11: Циклы

# %% [markdown]
# #### Вопросы:
#
# 1. Какие циклы ты знаешь?
# 2. Что такое бесконечный цикл и как его реализовать?
# 3. Какие функции - команды в циклах знаешь?

# %% [markdown]
# #### Практика
#
# Напиши несколько циклов (небесконечных)
